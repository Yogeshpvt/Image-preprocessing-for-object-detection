# %%
import os
import numpy as np
source_folder = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/images/train"
# fetch all files
my_array = []
for i in os.listdir(source_folder):
    k = i.split('.')
    y=k[0]
   # print(y)
    my_array.append(y)

# %%
my_array
# Out:
# ['Complete Blockage_0_0001',
#  'Complete Blockage_0_0002',
#  'Complete Blockage_0_0003',
#  'Complete Blockage_0_0005',
#  'Complete Blockage_0_0006',
#  'Complete Blockage_0_0008',
#  'Complete Blockage_0_0009',
#  'Complete Blockage_10_0001',
#  'Complete Blockage_10_0002',
#  'Complete Blockage_10_0003',
#  'Complete Blockage_10_0006',
#  'Complete Blockage_10_0007',
#  'Complete Blockage_10_0008',
#  'Complete Blockage_10_0009',
#  'Complete Blockage_11_0001',
#  'Complete Blockage_11_0002',
#  'Complete Blockage_11_0005',
#  'Complete Blockage_11_0006',
#  'Complete Blockage_11_0007',
#  'Complete Blockage_11_0008',
#  'Complete Blockage_11_0009',
#  'Complete Blockage_12_0001',
#  'Complete Blockage_12_0002',
#  'Complete Blockage_12_0005',
#  'Complete Blockage_12_0006',
#  'Complete Blockage_12_0007',
#  'Complete Blockage_12_0008',
#  'Complete Blockage_12_0009',
#  'Complete Blockage_13_0001',
#  'Complete Blockage_13_0002',
#  'Complete Blockage_13_0005',
# ...

# %%
import os
import numpy as np
source_folder1 = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/labels/train"
my_array1 = []
for i in os.listdir(source_folder1):
    k = i.split('.')
    y=k[0]
   # print(y)
    my_array1.append(y)

# %%
my_array1
# Out:
# ['Complete Blockage_0_0001',
#  'Complete Blockage_0_0002',
#  'Complete Blockage_0_0003',
#  'Complete Blockage_0_0005',
#  'Complete Blockage_0_0006',
#  'Complete Blockage_0_0008',
#  'Complete Blockage_0_0009',
#  'Complete Blockage_10_0001',
#  'Complete Blockage_10_0002',
#  'Complete Blockage_10_0003',
#  'Complete Blockage_10_0006',
#  'Complete Blockage_10_0007',
#  'Complete Blockage_10_0008',
#  'Complete Blockage_10_0009',
#  'Complete Blockage_11_0001',
#  'Complete Blockage_11_0002',
#  'Complete Blockage_11_0005',
#  'Complete Blockage_11_0006',
#  'Complete Blockage_11_0007',
#  'Complete Blockage_11_0008',
#  'Complete Blockage_11_0009',
#  'Complete Blockage_12_0001',
#  'Complete Blockage_12_0002',
#  'Complete Blockage_12_0005',
#  'Complete Blockage_12_0006',
#  'Complete Blockage_12_0007',
#  'Complete Blockage_12_0008',
#  'Complete Blockage_12_0009',
#  'Complete Blockage_13_0001',
#  'Complete Blockage_13_0002',
#  'Complete Blockage_13_0005',
# ...

# %%
n = len(my_array)
print(n)
# Out:
# 9385

# %%
for i in range(0,n):
    if my_array1[i] != my_array[i]:
        print(my_array[i])
        break
# Out:
# desktop

# %%
import os

# Set the paths to your image and label directories
image_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/images/val"
label_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/labels/val"

# Get a list of image file names
image_files = os.listdir(image_dir)

# Get a list of label file names
label_files = os.listdir(label_dir)

# Convert file names to a set for efficient comparison
image_set = set(image_files)
label_set = set(label_files)

# Find missing labels
missing_labels = image_set - label_set

# Print the missing labels
for missing_label in missing_labels:
    print(f"Missing label: {missing_label}")
# Out:
# Missing label: Partial Blockage_58_0006.jpg
# Missing label: joint_image_105_0009.jpg
# Missing label: Partial Blockage_0_0006.jpg
# Missing label: Partial Blockage_378_0007.jpg
# Missing label: stone_image_11_0026.jpg
# Missing label: Partial Blockage_416_0006.jpg
# Missing label: Partial Blockage_428_0007.jpg
# Missing label: joint_image_156.jpg
# Missing label: Encrustation_0_0026.jpg
# Missing label: joint_image_143_0008.jpg
# Missing label: Partial Blockage_114_0007.jpg
# Missing label: Partial Blockage_232_0006.jpg
# Missing label: Partial Blockage_250_0006.jpg
# Missing label: Partial Blockage_64_0006.jpg
# Missing label: Partial Blockage_320_0007.jpg
# Missing label: Partial Blockage_429_0007.jpg
# Missing label: Partial Blockage_193_0006.jpg
# Missing label: Complete Blockage_31_0007.jpg
# Missing label: Partial Blockage_208_0007.jpg
# Missing label: fracture_surface_damage_00332.jpg
# Missing label: Partial Blockage_226_0006.jpg
# ...

# %%
import os

# Set the paths to your image and label directories
image_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/images/val"
label_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/labels/val"

# Get a list of image file names without extensions
image_files = [os.path.splitext(file)[0] for file in os.listdir(image_dir)]

# Get a list of label file names without extensions
label_files = [os.path.splitext(file)[0] for file in os.listdir(label_dir)]

# Find missing labels
missing_labels = set(image_files) - set(label_files)

# Print the missing labels
for missing_label in missing_labels:
    print(f"Missing label: {missing_label}")
# Out:
# Missing label: desktop

# %%
import os

# Set the paths to your image and label directories
image_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/images/val"
label_dir = "C:/Users/YOGESH V/Desktop/Solinas intern/Solinas/fresh_water/Road_Sign_Dataset/labels/val"

# Get a list of image file names without extensions
image_files = [os.path.splitext(file)[0] for file in os.listdir(image_dir)]

# Get a list of label file names without extensions
label_files = [os.path.splitext(file)[0] for file in os.listdir(label_dir)]

# Find missing labels
missing_labels = set(image_files) - set(label_files)

# Print the missing labels
for missing_label in missing_labels:
    print(f"Missing label: {missing_label}")
# Out:
# Missing label: desktop
