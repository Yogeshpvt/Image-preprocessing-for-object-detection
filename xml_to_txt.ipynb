# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
random.seed(108)

# %%
# Function to get the data from XML Annotation
def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()
    
    # Initialise the info dict 
    info_dict = {}
    info_dict['bboxes'] = []

    # Parse the XML Tree
    for elem in root:
        # Get the file name 
        if elem.tag == "filename":
            info_dict['filename'] = elem.text
            
        # Get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))
            
            info_dict['image_size'] = tuple(image_size)
        
        # Get details of the bounding box 
        elif elem.tag == "object":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text
                    
                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)            
            info_dict['bboxes'].append(bbox)
    
    return info_dict

# %%
# Dictionary that maps class names to IDs
class_name_to_id_mapping = {"Joint_Displacement(JD,4)": 0,
                           "Crack_surface_damage(S,3)": 1,
                           "Sludge_Accumulation(Sl,3)": 2,
                           "Stone(St,3)": 3,
                           "Blockage(B,4)": 4,
                           "Fracture_surface_damage_(S,3)": 5
                           }

# %%
# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict):
    print_buffer = []
    
    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())
        
        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2 
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])
        
        # Normalise the co-ordinates by the dimensions of the image
        image_w, image_h, image_c = info_dict["image_size"]  
        b_center_x /= image_w 
        b_center_y /= image_h 
        b_width    /= image_w 
        b_height   /= image_h 
        
        #Write the bbox details to the file 
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
        
    # Name of the file which we have to save 
    save_file_name = os.path.join(info_dict["filename"].replace("jpg", "txt"))
    #save_file_name = os.path.join("train", info_dict["filename"].replace("jpg", "txt"))

    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))
    
# for x in os.listdir('E:/test - all/label_val'):
#   print(x)

# %%
for x in os.listdir('C:/Users/YOGESH V/Desktop/BlockageAI/road_sign_data/fracture_SD/labels'):
    print(x)
# Out:
# fracture_surface_damage_00000.xml
# fracture_surface_damage_00001.xml
# fracture_surface_damage_00002.xml
# fracture_surface_damage_00003.xml
# fracture_surface_damage_00004.xml
# fracture_surface_damage_00005.xml
# fracture_surface_damage_00006.xml
# fracture_surface_damage_00007.xml
# fracture_surface_damage_00008.xml
# fracture_surface_damage_00009.xml
# fracture_surface_damage_00010.xml
# fracture_surface_damage_00011.xml
# fracture_surface_damage_00012.xml
# fracture_surface_damage_00013.xml
# fracture_surface_damage_00014.xml
# fracture_surface_damage_00015.xml
# fracture_surface_damage_00016.xml
# fracture_surface_damage_00017.xml
# fracture_surface_damage_00018.xml
# fracture_surface_damage_00019.xml
# fracture_surface_damage_00020.xml
# fracture_surface_damage_00021.xml
# fracture_surface_damage_00022.xml
# fracture_surface_damage_00023.xml
# fracture_surface_damage_00024.xml
# fracture_surface_damage_00025.xml
# fracture_surface_damage_00026.xml
# fracture_surface_damage_00027.xml
# fracture_surface_damage_00028.xml
# fracture_surface_damage_00029.xml
# fracture_surface_damage_00030.xml
# fracture_surface_damage_00031.xml
# fracture_surface_damage_00032.xml
# fracture_surface_damage_00033.xml
# fracture_surface_damage_00034.xml
# fracture_surface_damage_00035.xml
# fracture_surface_damage_00036.xml
# fracture_surface_damage_00037.xml
# fracture_surface_damage_00038.xml
# fracture_surface_damage_00039.xml
# fracture_surface_damage_00040.xml
# fracture_surface_damage_00041.xml
# fracture_surface_damage_00042.xml
# fracture_surface_damage_00043.xml
# fracture_surface_damage_00044.xml
# fracture_surface_damage_00045.xml
# fracture_surface_damage_00046.xml
# fracture_surface_damage_00047.xml
# fracture_surface_damage_00048.xml
# fracture_surface_damage_00049.xml
# fracture_surface_damage_00050.xml
# fracture_surface_damage_00051.xml
# fracture_surface_damage_00052.xml
# fracture_surface_damage_00053.xml
# fracture_surface_damage_00054.xml
# fracture_surface_damage_00055.xml
# fracture_surface_damage_00056.xml
# fracture_surface_damage_00057.xml
# fracture_surface_damage_00058.xml
# fracture_surface_damage_00059.xml
# fracture_surface_damage_00060.xml
# fracture_surface_damage_00061.xml
# fracture_surface_damage_00062.xml
# fracture_surface_damage_00063.xml
# fracture_surface_damage_00064.xml
# fracture_surface_damage_00065.xml
# fracture_surface_damage_00066.xml
# fracture_surface_damage_00067.xml
# fracture_surface_damage_00068.xml
# fracture_surface_damage_00069.xml
# fracture_surface_damage_00070.xml
# fracture_surface_damage_00071.xml
# fracture_surface_damage_00072.xml
# fracture_surface_damage_00073.xml
# fracture_surface_damage_00074.xml
# fracture_surface_damage_00075.xml
# fracture_surface_damage_00076.xml
# fracture_surface_damage_00077.xml
# fracture_surface_damage_00078.xml
# fracture_surface_damage_00079.xml
# fracture_surface_damage_00080.xml
# fracture_surface_damage_00081.xml
# fracture_surface_damage_00082.xml
# fracture_surface_damage_00083.xml
# fracture_surface_damage_00084.xml
# fracture_surface_damage_00085.xml
# fracture_surface_damage_00086.xml
# fracture_surface_damage_00087.xml
# fracture_surface_damage_00088.xml
# fracture_surface_damage_00089.xml
# fracture_surface_damage_00090.xml
# fracture_surface_damage_00091.xml
# fracture_surface_damage_00092.xml
# fracture_surface_damage_00093.xml
# fracture_surface_damage_00094.xml
# fracture_surface_damage_00095.xml
# fracture_surface_damage_00096.xml
# fracture_surface_damage_00097.xml
# fracture_surface_damage_00098.xml
# fracture_surface_damage_00099.xml
# fracture_surface_damage_00100.xml
# fracture_surface_damage_00101.xml
# fracture_surface_damage_00102.xml
# fracture_surface_damage_00103.xml
# fracture_surface_damage_00104.xml
# fracture_surface_damage_00105.xml
# fracture_surface_damage_00106.xml
# fracture_surface_damage_00107.xml
# fracture_surface_damage_00108.xml
# fracture_surface_damage_00109.xml
# fracture_surface_damage_00110.xml
# fracture_surface_damage_00111.xml
# fracture_surface_damage_00112.xml
# fracture_surface_damage_00113.xml
# fracture_surface_damage_00114.xml
# fracture_surface_damage_00115.xml
# fracture_surface_damage_00116.xml
# fracture_surface_damage_00117.xml
# fracture_surface_damage_00118.xml
# fracture_surface_damage_00119.xml
# fracture_surface_damage_00120.xml
# fracture_surface_damage_00121.xml
# fracture_surface_damage_00122.xml
# fracture_surface_damage_00123.xml
# fracture_surface_damage_00124.xml
# fracture_surface_damage_00125.xml
# fracture_surface_damage_00126.xml
# fracture_surface_damage_00127.xml
# fracture_surface_damage_00128.xml
# fracture_surface_damage_00129.xml
# fracture_surface_damage_00130.xml
# fracture_surface_damage_00131.xml
# fracture_surface_damage_00132.xml
# fracture_surface_damage_00133.xml
# fracture_surface_damage_00134.xml
# fracture_surface_damage_00135.xml
# fracture_surface_damage_00136.xml
# fracture_surface_damage_00137.xml
# fracture_surface_damage_00138.xml
# fracture_surface_damage_00139.xml
# fracture_surface_damage_00140.xml
# fracture_surface_damage_00141.xml
# fracture_surface_damage_00142.xml
# fracture_surface_damage_00143.xml
# fracture_surface_damage_00144.xml
# fracture_surface_damage_00145.xml
# fracture_surface_damage_00146.xml
# fracture_surface_damage_00147.xml
# fracture_surface_damage_00148.xml
# fracture_surface_damage_00149.xml
# fracture_surface_damage_00150.xml
# fracture_surface_damage_00151.xml
# fracture_surface_damage_00152.xml
# fracture_surface_damage_00153.xml
# fracture_surface_damage_00154.xml
# fracture_surface_damage_00155.xml
# fracture_surface_damage_00156.xml
# fracture_surface_damage_00157.xml
# fracture_surface_damage_00158.xml
# fracture_surface_damage_00159.xml
# fracture_surface_damage_00160.xml
# fracture_surface_damage_00161.xml
# fracture_surface_damage_00162.xml
# fracture_surface_damage_00163.xml
# fracture_surface_damage_00164.xml
# fracture_surface_damage_00165.xml
# fracture_surface_damage_00166.xml
# fracture_surface_damage_00167.xml
# fracture_surface_damage_00168.xml
# fracture_surface_damage_00169.xml
# fracture_surface_damage_00170.xml
# fracture_surface_damage_00171.xml
# fracture_surface_damage_00172.xml
# fracture_surface_damage_00173.xml
# fracture_surface_damage_00174.xml
# fracture_surface_damage_00175.xml
# fracture_surface_damage_00176.xml
# fracture_surface_damage_00177.xml
# fracture_surface_damage_00178.xml
# fracture_surface_damage_00179.xml
# fracture_surface_damage_00180.xml
# fracture_surface_damage_00181.xml
# fracture_surface_damage_00182.xml
# fracture_surface_damage_00183.xml
# fracture_surface_damage_00184.xml
# fracture_surface_damage_00185.xml
# fracture_surface_damage_00186.xml
# fracture_surface_damage_00187.xml
# fracture_surface_damage_00188.xml
# fracture_surface_damage_00189.xml
# fracture_surface_damage_00190.xml
# fracture_surface_damage_00191.xml
# fracture_surface_damage_00192.xml
# fracture_surface_damage_00193.xml
# fracture_surface_damage_00194.xml
# fracture_surface_damage_00195.xml
# fracture_surface_damage_00196.xml
# fracture_surface_damage_00197.xml
# fracture_surface_damage_00198.xml
# fracture_surface_damage_00199.xml
# fracture_surface_damage_00200.xml
# fracture_surface_damage_00201.xml
# fracture_surface_damage_00202.xml
# fracture_surface_damage_00203.xml
# fracture_surface_damage_00204.xml
# fracture_surface_damage_00205.xml
# fracture_surface_damage_00206.xml
# fracture_surface_damage_00207.xml
# fracture_surface_damage_00208.xml
# fracture_surface_damage_00209.xml
# fracture_surface_damage_00210.xml
# fracture_surface_damage_00211.xml
# fracture_surface_damage_00212.xml
# fracture_surface_damage_00213.xml
# fracture_surface_damage_00214.xml
# fracture_surface_damage_00215.xml
# fracture_surface_damage_00216.xml
# fracture_surface_damage_00217.xml
# fracture_surface_damage_00218.xml
# fracture_surface_damage_00219.xml
# fracture_surface_damage_00220.xml
# fracture_surface_damage_00221.xml
# fracture_surface_damage_00222.xml
# fracture_surface_damage_00223.xml
# fracture_surface_damage_00224.xml
# fracture_surface_damage_00225.xml
# fracture_surface_damage_00226.xml
# fracture_surface_damage_00227.xml
# fracture_surface_damage_00228.xml
# fracture_surface_damage_00229.xml
# fracture_surface_damage_00230.xml
# fracture_surface_damage_00231.xml
# fracture_surface_damage_00232.xml
# fracture_surface_damage_00233.xml
# fracture_surface_damage_00234.xml
# fracture_surface_damage_00235.xml
# fracture_surface_damage_00236.xml
# fracture_surface_damage_00237.xml
# fracture_surface_damage_00238.xml
# fracture_surface_damage_00239.xml
# fracture_surface_damage_00240.xml
# fracture_surface_damage_00241.xml
# fracture_surface_damage_00242.xml
# fracture_surface_damage_00243.xml
# fracture_surface_damage_00244.xml
# fracture_surface_damage_00245.xml
# fracture_surface_damage_00246.xml
# fracture_surface_damage_00247.xml
# fracture_surface_damage_00248.xml
# fracture_surface_damage_00249.xml
# fracture_surface_damage_00250.xml
# fracture_surface_damage_00251.xml
# fracture_surface_damage_00252.xml
# fracture_surface_damage_00253.xml
# fracture_surface_damage_00254.xml
# fracture_surface_damage_00255.xml
# fracture_surface_damage_00256.xml
# fracture_surface_damage_00257.xml
# fracture_surface_damage_00258.xml
# fracture_surface_damage_00259.xml
# fracture_surface_damage_00260.xml
# fracture_surface_damage_00261.xml
# fracture_surface_damage_00262.xml
# fracture_surface_damage_00263.xml
# fracture_surface_damage_00264.xml
# fracture_surface_damage_00265.xml
# fracture_surface_damage_00266.xml
# fracture_surface_damage_00267.xml
# fracture_surface_damage_00268.xml
# fracture_surface_damage_00269.xml
# fracture_surface_damage_00270.xml
# fracture_surface_damage_00271.xml
# fracture_surface_damage_00272.xml
# fracture_surface_damage_00273.xml
# fracture_surface_damage_00274.xml
# fracture_surface_damage_00275.xml
# fracture_surface_damage_00276.xml
# fracture_surface_damage_00277.xml
# fracture_surface_damage_00278.xml
# fracture_surface_damage_00279.xml
# fracture_surface_damage_00280.xml
# fracture_surface_damage_00281.xml
# fracture_surface_damage_00282.xml
# fracture_surface_damage_00283.xml
# fracture_surface_damage_00284.xml
# fracture_surface_damage_00285.xml
# fracture_surface_damage_00286.xml
# fracture_surface_damage_00287.xml
# fracture_surface_damage_00288.xml
# fracture_surface_damage_00289.xml
# fracture_surface_damage_00290.xml
# fracture_surface_damage_00291.xml
# fracture_surface_damage_00292.xml
# fracture_surface_damage_00293.xml
# fracture_surface_damage_00294.xml
# fracture_surface_damage_00295.xml
# fracture_surface_damage_00296.xml
# fracture_surface_damage_00297.xml
# fracture_surface_damage_00298.xml
# fracture_surface_damage_00299.xml
# fracture_surface_damage_00300.xml
# fracture_surface_damage_00301.xml
# fracture_surface_damage_00302.xml
# fracture_surface_damage_00303.xml
# fracture_surface_damage_00304.xml
# fracture_surface_damage_00305.xml
# fracture_surface_damage_00306.xml
# fracture_surface_damage_00307.xml
# fracture_surface_damage_00308.xml
# fracture_surface_damage_00309.xml
# fracture_surface_damage_00310.xml
# fracture_surface_damage_00311.xml
# fracture_surface_damage_00312.xml
# fracture_surface_damage_00313.xml
# fracture_surface_damage_00314.xml
# fracture_surface_damage_00315.xml
# fracture_surface_damage_00316.xml
# fracture_surface_damage_00317.xml
# fracture_surface_damage_00318.xml
# fracture_surface_damage_00319.xml
# fracture_surface_damage_00320.xml
# fracture_surface_damage_00321.xml
# fracture_surface_damage_00322.xml
# fracture_surface_damage_00323.xml
# fracture_surface_damage_00324.xml
# fracture_surface_damage_00325.xml
# fracture_surface_damage_00326.xml
# fracture_surface_damage_00327.xml
# fracture_surface_damage_00328.xml
# fracture_surface_damage_00329.xml
# fracture_surface_damage_00330.xml
# fracture_surface_damage_00331.xml
# fracture_surface_damage_00332.xml
# fracture_surface_damage_00333.xml
# fracture_surface_damage_00334.xml
# fracture_surface_damage_00335.xml
# fracture_surface_damage_00336.xml
# fracture_surface_damage_00337.xml
# fracture_surface_damage_00338.xml
# fracture_surface_damage_00339.xml

# %%
test = [os.path.join(x) for x in os.listdir('C:/Users/YOGESH V/Desktop/BlockageAI/road_sign_data/fracture_SD/labels') if x[-3:] == "xml"]
test.sort()

for ann in tqdm(test):
    info_dict = extract_info_from_xml('C:/Users/YOGESH V/Desktop/BlockageAI/road_sign_data/fracture_SD/labels/'+ ann)
    convert_to_yolov5(info_dict)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 340/340 [00:00<00:00, 1680.72it/s]
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
# Invalid Class. Must be one from  dict_keys(['Joint_Displacement(JD,4)', 'Crack_surface_damage(S,3)', 'Sludge_Accumulation(Sl,3)', 'Stone(St,3)', 'Blockage(B,4)', 'Fracture_surface_damage_(S,3)'])
